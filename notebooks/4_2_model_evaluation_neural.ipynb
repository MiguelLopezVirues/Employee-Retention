# %% [markdown]
# ### 0. Imports

# %%
# %load_ext autoreload
# %autoreload 2

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
import math

# Visualizaciones
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Vigilar progreso bucles
# -----------------------------------------------------------------------
from tqdm import tqdm

# Gestionar los warnings
# -----------------------------------------------------------------------
import warnings

# modificar el path
# -----------------------------------------------------------------------
import sys
sys.path.append("..")

# # importar funciones de soporte
# # -----------------------------------------------------------------------
import src.soporte_eda as se
import src.data_preparation as dp
# import src.soporte_ajuste_clasificacion as sac
import src.data_visualization_support as dvs
# import src.model_evaluation_support as mes


# preprocesamiento
# -----------------------------------------------------------------------
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# encoding
# -----------------------------------------------------------------------
from sklearn.preprocessing import  OneHotEncoder
import category_encoders as ce
# set category encoder compatibility
import sklearn
sklearn.set_config(transform_output="pandas")


# evaluar objetos literales
# -----------------------------------------------------------------------
from ast import literal_eval 

# statistics functions
# -----------------------------------------------------------------------
from scipy.stats import pearsonr, spearmanr, pointbiserialr


# definir semilla random
# -----------------------------------------------------------------------
seed = 42

import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier, KerasRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, Dense
from keras_tuner import RandomSearch, Objective
# Out:
# 2025-01-09 11:09:23.670720: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-09 11:09:24.363522: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736417364.530240   72940 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736417364.564781   72940 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 11:09:24.892564: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 1. Introduction - Model Evaluation - Neural Network

# %% [markdown]
# In this notebook, the goal is not other than to expand the model evaluation carried out `notebooks/4_model_evaluation.ipynb`, by adding an evaluation of neural networks for this task.

# %% [markdown]
# # 2. Data import and preparation

# %% [markdown]
# ## 2.1 Data preparation

# %% [markdown]
# Data preparation for load, cleaning and correction of errors found throughout the 1_exploration_cleaning, 2_EDA and 3_preprocessing notebooks have been integrated into a load and clean function, available at ``src/data_preparation.py``.

# %%
list_of_paths = ["../data/general_data.csv","../data/employee_survey_data.csv","../data/manager_survey_data.csv"]

employee_attrition = dp.load_and_clean(list_of_paths, "EmployeeID")
employee_attrition
# Out:
# /mnt/c/Users/Miguel/Desktop/Hackio/Proyectos/8.Retencion_Empleados/notebooks/../src/data_preparation.py:86: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   employee_attrition = employee_attrition.replace(repl_dict)
#       age  attrition     businesstravel              department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4226   36          0      Travel_Rarely  Research & Development
# 4305   45          0      Travel_Rarely                   Sales
# 4332   31          0      Travel_Rarely                   Sales
# 4395   40          0      Travel_Rarely  Research & Development
# 4409   40          0      Travel_Rarely  Research & Development
#
#       distancefromhome education    educationfield  gender joblevel  \
# 0                    6         2     Life Sciences  Female        1
# 1                   10         1     Life Sciences  Female        1
# 2                   17         4             Other    Male        4
# 3                    2         5     Life Sciences    Male        3
# 4                   10         1           Medical    Male        1
# ...                ...       ...               ...     ...      ...
# 4226                 2         3     Life Sciences    Male        2
# 4305                 1         4  Technical Degree    Male        1
# 4332                 2         5     Life Sciences    Male        2
# 4395                 2         3     Life Sciences    Male        1
# 4409                28         3           Medical    Male        2
#
#                         jobrole  ... totalworkingyears  trainingtimeslastyear  \
# 0     Healthcare Representative  ...               1.0                      6
# 1            Research Scientist  ...               6.0                      3
# 2               Sales Executive  ...               5.0                      2
# 3               Human Resources  ...              13.0                      5
# 4               Sales Executive  ...               9.0                      2
# ...                         ...  ...               ...                    ...
# 4226       Sales Representative  ...               5.0                      2
# 4305         Research Scientist  ...              20.0                      3
# 4332       Sales Representative  ...               7.0                      3
# 4395     Manufacturing Director  ...               9.0                      4
# 4409      Laboratory Technician  ...               NaN                      6
#
#      yearsatcompany yearssincelastpromotion yearswithcurrmanager  \
# 0               1.0                       0                    0
# 1               5.0                       1                    4
# 2               5.0                       0                    3
# 3               8.0                       7                    5
# 4               6.0                       0                    4
# ...             ...                     ...                  ...
# 4226            1.0                       0                    0
# 4305           17.0                       0           10 or more
# 4332            4.0                       0                    2
# 4395            9.0                       4                    7
# 4409           21.0                       3                    9
#
#       environmentsatisfaction jobsatisfaction  worklifebalance jobinvolvement  \
# 0                         3.0             4.0              2.0              3
# 1                         3.0             2.0              4.0              2
# 2                         2.0             2.0              1.0              3
# 3                         4.0             4.0              3.0              2
# 4                         4.0             1.0              3.0              3
# ...                       ...             ...              ...            ...
# 4226                      2.0             4.0              3.0              3
# 4305                      2.0             2.0              nan              3
# 4332                      nan             4.0              3.0              4
# 4395                      1.0             4.0              3.0              2
# 4409                      1.0             3.0              nan              4
#
#      performancerating
# 0                    3
# 1                    4
# 2                    3
# 3                    3
# 4                    3
# ...                ...
# 4226                 3
# 4305                 3
# 4332                 3
# 4395                 3
# 4409                 3
#
# [1573 rows x 25 columns]

# %% [markdown]
# ## 2.2 Define target and predictors

# %% [markdown]
# Define target and predictors, perform train-test split.

# %%
y = employee_attrition["attrition"]
X = employee_attrition.drop(columns="attrition")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed)

# %% [markdown]
# Perform train and test split. Define a stratified kfold cross validation to improve metric robustness in face of target imbalance. Optimize for minimal average_precision_score, which is the equivalent of the area under the Precision-Recall curve, which is more informative than AUC for imbalanced datasets.

# %%
cross_val = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

score = "average_precision"

verbosity = 2

# %% [markdown]
# # 3. Model evaluation

# %% [markdown]
# ## 3.1 Experiment 1 - baseline

# %% [markdown]
# ### 3.1.1 Data preprocessing

# %% [markdown]
# - Missing: Median imputation for numerical features. Mode for categorical.
# - Outliers: False.
# - Encoding: One hot encoder for <= 3 categories. Target for others.
# - Scaling: False. (Only tree based models will be used)

# %% [markdown]
# Setting the conditions for data preprocessing:

# %%
categorical = X.select_dtypes("object").columns.to_list()

# current numpy version doesn't work well with np.number for this:
numerical = X.select_dtypes(["int64","float64"]).columns.to_list()

all_columns = X.columns.to_list()

columns_one_hot = [col for col in categorical if X[col].nunique() <= 3]
columns_target =[col for col in categorical if X[col].nunique() > 3]


imputer = ColumnTransformer(
    transformers=[
        ('num_imputer', SimpleImputer(strategy='median'), numerical),
        ('cat_imputer', SimpleImputer(strategy='most_frequent'), categorical),
    ],
    remainder='drop',
    verbose_feature_names_out=False  # Prevents prefixing
)

scaler = MinMaxScaler()

# Combine into a pipeline to later append the model
def build_pipeline():
    return Pipeline([
        ('imputer', imputer),
        ('one-hot-encoder', ce.OneHotEncoder(cols=columns_one_hot, drop_invariant=True, return_df=True,use_cat_names=True)),
        ('target-encoder', ce.TargetEncoder(cols=columns_target, drop_invariant=False, return_df=True))
        # ('scaler', scaler)
    ])

# %% [markdown]
# Checking the preprocessing pipeline:

# %%
preprocessing_pipeline_target = build_pipeline()

# %%
preprocessing_pipeline_target.fit_transform(X, y)
# Out:
#        age  distancefromhome  monthlyincome  totalworkingyears  \
# 0     51.0               6.0       131160.0                1.0
# 1     31.0              10.0        41890.0                6.0
# 2     32.0              17.0       193280.0                5.0
# 3     38.0               2.0        83210.0               13.0
# 4     32.0              10.0        23420.0                9.0
# ...    ...               ...            ...                ...
# 4226  36.0               2.0        43200.0                5.0
# 4305  45.0               1.0        25800.0               20.0
# 4332  31.0               2.0        27280.0                7.0
# 4395  40.0               2.0        27180.0                9.0
# 4409  40.0              28.0        54680.0               10.0
#
#       yearsatcompany  businesstravel_Travel_Rarely  \
# 0                1.0                             1
# 1                5.0                             0
# 2                5.0                             0
# 3                8.0                             0
# 4                6.0                             1
# ...              ...                           ...
# 4226             1.0                             1
# 4305            17.0                             1
# 4332             4.0                             1
# 4395             9.0                             1
# 4409            21.0                             1
#
#       businesstravel_Travel_Frequently  businesstravel_Non-Travel  \
# 0                                    0                          0
# 1                                    1                          0
# 2                                    1                          0
# 3                                    0                          1
# 4                                    0                          0
# ...                                ...                        ...
# 4226                                 0                          0
# 4305                                 0                          0
# 4332                                 0                          0
# 4395                                 0                          0
# 4409                                 0                          0
#
#       department_Sales  department_Research & Development  ...  \
# 0                    1                                  0  ...
# 1                    0                                  1  ...
# 2                    0                                  1  ...
# 3                    0                                  1  ...
# 4                    0                                  1  ...
# ...                ...                                ...  ...
# 4226                 0                                  1  ...
# 4305                 1                                  0  ...
# 4332                 1                                  0  ...
# 4395                 0                                  1  ...
# 4409                 0                                  1  ...
#
#       stockoptionlevel  trainingtimeslastyear  yearssincelastpromotion  \
# 0              0.16568               0.057833                    0.192
# 1             0.151326               0.172414                 0.137931
# 2             0.166661               0.174873                    0.192
# 3             0.166661               0.131783                  0.19994
# 4             0.168675               0.174873                    0.192
# ...                ...                    ...                      ...
# 4226           0.16568               0.174873                    0.192
# 4305          0.166661               0.172414                    0.192
# 4332           0.16568               0.172414                    0.192
# 4395          0.151326                0.12782                 0.073112
# 4409           0.16568               0.057833                  0.16947
#
#       yearswithcurrmanager  environmentsatisfaction  jobsatisfaction  \
# 0                 0.313793                 0.139004         0.112245
# 1                 0.116516                 0.139004         0.165541
# 2                  0.14094                 0.148026         0.165541
# 3                 0.136817                 0.133333         0.112245
# 4                 0.116516                 0.133333         0.229236
# ...                    ...                      ...              ...
# 4226              0.313793                 0.148026         0.112245
# 4305              0.057715                 0.148026         0.165541
# 4332              0.145604                 0.168079         0.112245
# 4395              0.133047                 0.247492         0.112245
# 4409              0.087498                 0.247492         0.166667
#
#       worklifebalance  jobinvolvement  performancerating_3  \
# 0            0.170868        0.154341                    1
# 1            0.179487        0.156962                    0
# 2            0.324999        0.154341                    1
# 3            0.140127        0.156962                    1
# 4            0.140127        0.154341                    1
# ...               ...             ...                  ...
# 4226         0.140127        0.154341                    1
# 4305         0.122662        0.154341                    1
# 4332         0.140127        0.174194                    1
# 4395         0.140127        0.156962                    1
# 4409         0.122662        0.174194                    1
#
#       performancerating_4
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 4226                    0
# 4305                    0
# 4332                    0
# 4395                    0
# 4409                    0
#
# [1573 rows x 32 columns]

# %% [markdown]
# ### 3.1.2 Models to compare

# %% [markdown]
# The model to train and compare with previous metrics will be a Deep Neural Network. An evaluation of different configurations will be made.

# %% [markdown]
# ### 3.1.3 Run experiment

# %% [markdown]
# Hyperparameters to tune, in order according to Andrew Ng in Deep Learning Specialization (I believe for Adam optimizer):
#  Most important:
# - Learning rate $\alpha$: the most important to tune.
#
#  Second in importance:
# - Momentum $\beta$: It can be set at $\beta \approx 0.9$.
# - Mini-batch size
# - n of hidden units
#
# Third in importance:
# - n of layers (I am unsure about this, as he said that deepening the layers is equivalent to using a huge number of hidden units)
# - learning rate decay
# - $\beta_1, \beta_2, \epsilon$ (0.9,0.999,$10^{-8}$): almost never touched.

# %%
#things to do
# [X] find a way to introduce regularization
# [X] add AUC-PR as a metric
# [X] tune hyperparameters for train/val/test
#   [X] regularization beta
#   [X] learning rate
#   [X] number of units
# [] tune hyperparameters in cross-validation scheme
# [] inspect the plots of AUC-PR and loss function of the hyperparameter tuning
# [] convert to numpy arrays or tf tensors after transformation
# [] document about the behaviour of the tuner with respect to early stopping and epoch score
# [] document snippets
# [] investigar arquitectura hidden units

def reduce_num_precision(X,y):
    for col in X.select_dtypes(include=["float"]).columns:
            X[col] = X[col].astype("float32")

    for col in X.select_dtypes(include=["int"]).columns:
            X[col] = X[col].astype("int32")

    y = y.astype("int32")
    
    return X, y


X_train_transformed = preprocessing_pipeline_target.fit_transform(X_train,y_train)

X_train_transformed, y_train = reduce_num_precision(X_train_transformed, y_train)

X_test_transformed = preprocessing_pipeline_target.transform(X_test)

X_test_transformed, y_test = reduce_num_precision(X_test_transformed, y_test)


def build_model():
    model = Sequential([
            Input(shape=(X_train_transformed.shape[1],)),
            BatchNormalization(),
            Dense(units=128,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=64,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=32,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=32,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=16,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=8,activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.5)),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=1,activation="sigmoid")
        ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                    loss="binary_crossentropy", 
                    metrics=[
                        tf.keras.metrics.AUC(curve="PR", name="auc_pr")  # AUC-PR metric
                    ])
    return model

model = build_model()

history = model.fit(X_train_transformed,y_train, validation_data=(X_test_transformed, y_test), epochs=100, batch_size=64)
# Out:
# I0000 00:00:1736417371.699213   72940 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3539 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736417377.259935   73047 service.cc:148] XLA service 0x7ff7b4014a10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736417377.260538   73047 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2025-01-09 11:09:37.451737: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736417378.105296   73047 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  8/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.1533 - loss: 120.7923
# I0000 00:00:1736417382.306418   73047 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 402ms/step - auc_pr: 0.1595 - loss: 116.0910 - val_auc_pr: 0.1255 - val_loss: 95.0365
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.1705 - loss: 89.4407 - val_auc_pr: 0.1676 - val_loss: 72.7040
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.1790 - loss: 68.5195 - val_auc_pr: 0.1379 - val_loss: 55.6176
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.1777 - loss: 52.4843 - val_auc_pr: 0.1298 - val_loss: 42.6603
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.2642 - loss: 40.2743 - val_auc_pr: 0.1382 - val_loss: 32.8088
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.1828 - loss: 31.0819 - val_auc_pr: 0.1522 - val_loss: 25.3307
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.2142 - loss: 24.0372 - val_auc_pr: 0.1564 - val_loss: 19.6308
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.2728 - loss: 18.6283 - val_auc_pr: 0.1964 - val_loss: 15.2755
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.2526 - loss: 14.5326 - val_auc_pr: 0.1587 - val_loss: 11.9588
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.2928 - loss: 11.4207 - val_auc_pr: 0.1587 - val_loss: 9.4451
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3588 - loss: 9.0202 - val_auc_pr: 0.1593 - val_loss: 7.5190
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3532 - loss: 7.1881 - val_auc_pr: 0.1587 - val_loss: 6.0168
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3809 - loss: 5.7691 - val_auc_pr: 0.2332 - val_loss: 4.8493
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3163 - loss: 4.6636 - val_auc_pr: 0.1743 - val_loss: 3.9696
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.3396 - loss: 3.8312 - val_auc_pr: 0.1587 - val_loss: 3.2744
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3625 - loss: 3.1837 - val_auc_pr: 0.1587 - val_loss: 2.7260
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3435 - loss: 2.6523 - val_auc_pr: 0.1592 - val_loss: 2.2921
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.3801 - loss: 2.2348 - val_auc_pr: 0.1587 - val_loss: 1.9512
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3414 - loss: 1.9313 - val_auc_pr: 0.2543 - val_loss: 1.6773
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3843 - loss: 1.5947 - val_auc_pr: 0.1743 - val_loss: 1.4380
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3653 - loss: 1.3816 - val_auc_pr: 0.1587 - val_loss: 1.2628
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4735 - loss: 1.1846 - val_auc_pr: 0.2003 - val_loss: 1.1176
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4285 - loss: 1.0779 - val_auc_pr: 0.2479 - val_loss: 1.0078
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.3716 - loss: 0.9758 - val_auc_pr: 0.2789 - val_loss: 0.9113
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - auc_pr: 0.4000 - loss: 0.8520 - val_auc_pr: 0.3192 - val_loss: 0.8301
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.3906 - loss: 0.8007 - val_auc_pr: 0.3375 - val_loss: 0.7663
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4703 - loss: 0.7093 - val_auc_pr: 0.3019 - val_loss: 0.7125
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.4059 - loss: 0.6648 - val_auc_pr: 0.3116 - val_loss: 0.6800
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4368 - loss: 0.6125 - val_auc_pr: 0.3761 - val_loss: 0.6457
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4717 - loss: 0.5688 - val_auc_pr: 0.3667 - val_loss: 0.6095
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4281 - loss: 0.5562 - val_auc_pr: 0.3084 - val_loss: 0.5866
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4035 - loss: 0.5141 - val_auc_pr: 0.3573 - val_loss: 0.5711
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4233 - loss: 0.5118 - val_auc_pr: 0.3583 - val_loss: 0.5528
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4472 - loss: 0.5180 - val_auc_pr: 0.3376 - val_loss: 0.5429
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4341 - loss: 0.4815 - val_auc_pr: 0.3835 - val_loss: 0.5239
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4108 - loss: 0.4671 - val_auc_pr: 0.2921 - val_loss: 0.5142
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3785 - loss: 0.4926 - val_auc_pr: 0.3750 - val_loss: 0.5021
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5094 - loss: 0.4657 - val_auc_pr: 0.3582 - val_loss: 0.4994
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3481 - loss: 0.4552 - val_auc_pr: 0.3659 - val_loss: 0.4896
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4402 - loss: 0.4572 - val_auc_pr: 0.3823 - val_loss: 0.4898
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.4445 - loss: 0.4707 - val_auc_pr: 0.3597 - val_loss: 0.4796
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4992 - loss: 0.4363 - val_auc_pr: 0.3707 - val_loss: 0.4839
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4667 - loss: 0.4231 - val_auc_pr: 0.3825 - val_loss: 0.4675
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4238 - loss: 0.4052 - val_auc_pr: 0.3481 - val_loss: 0.4665
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.5329 - loss: 0.4183 - val_auc_pr: 0.3461 - val_loss: 0.4821
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4589 - loss: 0.4356 - val_auc_pr: 0.3707 - val_loss: 0.4704
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4773 - loss: 0.4301 - val_auc_pr: 0.3852 - val_loss: 0.4557
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4619 - loss: 0.4409 - val_auc_pr: 0.3974 - val_loss: 0.4453
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.4633 - loss: 0.4258 - val_auc_pr: 0.3585 - val_loss: 0.4683
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4527 - loss: 0.4450 - val_auc_pr: 0.4464 - val_loss: 0.4531
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4902 - loss: 0.3800 - val_auc_pr: 0.3393 - val_loss: 0.4657
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4639 - loss: 0.4066 - val_auc_pr: 0.3608 - val_loss: 0.4460
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4339 - loss: 0.4341 - val_auc_pr: 0.3781 - val_loss: 0.4650
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.5059 - loss: 0.4160 - val_auc_pr: 0.3559 - val_loss: 0.4685
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4221 - loss: 0.3920 - val_auc_pr: 0.3477 - val_loss: 0.4651
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4650 - loss: 0.4336 - val_auc_pr: 0.3592 - val_loss: 0.4738
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.4153 - loss: 0.4269 - val_auc_pr: 0.3309 - val_loss: 0.4630
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.5549 - loss: 0.3732 - val_auc_pr: 0.3751 - val_loss: 0.4614
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4829 - loss: 0.4224 - val_auc_pr: 0.3436 - val_loss: 0.4665
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.5245 - loss: 0.4188 - val_auc_pr: 0.3511 - val_loss: 0.4549
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4787 - loss: 0.4132 - val_auc_pr: 0.3267 - val_loss: 0.5011
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5172 - loss: 0.3962 - val_auc_pr: 0.3539 - val_loss: 0.4579
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.5846 - loss: 0.3645 - val_auc_pr: 0.3479 - val_loss: 0.4529
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.4721 - loss: 0.4150 - val_auc_pr: 0.3802 - val_loss: 0.4405
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4679 - loss: 0.4048 - val_auc_pr: 0.2689 - val_loss: 0.4939
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4040 - loss: 0.4048 - val_auc_pr: 0.3449 - val_loss: 0.5229
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.4617 - loss: 0.4220 - val_auc_pr: 0.3335 - val_loss: 0.4506
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.5464 - loss: 0.3648 - val_auc_pr: 0.3196 - val_loss: 0.4939
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4768 - loss: 0.4095 - val_auc_pr: 0.3264 - val_loss: 0.4648
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5144 - loss: 0.3934 - val_auc_pr: 0.3451 - val_loss: 0.4889
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4683 - loss: 0.3836 - val_auc_pr: 0.3340 - val_loss: 0.5214
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5915 - loss: 0.3613 - val_auc_pr: 0.3778 - val_loss: 0.4408
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.5059 - loss: 0.4016 - val_auc_pr: 0.4104 - val_loss: 0.4909
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5311 - loss: 0.4062 - val_auc_pr: 0.3465 - val_loss: 0.4552
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.4558 - loss: 0.3925 - val_auc_pr: 0.3035 - val_loss: 0.5067
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5113 - loss: 0.3948 - val_auc_pr: 0.3017 - val_loss: 0.4971
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5616 - loss: 0.3767 - val_auc_pr: 0.3596 - val_loss: 0.5035
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.5752 - loss: 0.3893 - val_auc_pr: 0.3114 - val_loss: 0.4827
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - auc_pr: 0.6179 - loss: 0.3505 - val_auc_pr: 0.3885 - val_loss: 0.4782
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.5572 - loss: 0.3791 - val_auc_pr: 0.3211 - val_loss: 0.5544
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4678 - loss: 0.4024 - val_auc_pr: 0.3240 - val_loss: 0.4805
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.4993 - loss: 0.3880 - val_auc_pr: 0.3300 - val_loss: 0.4576
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.5752 - loss: 0.4011 - val_auc_pr: 0.3284 - val_loss: 0.4726
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.6101 - loss: 0.3688 - val_auc_pr: 0.3290 - val_loss: 0.5069
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.5415 - loss: 0.3967 - val_auc_pr: 0.3131 - val_loss: 0.4873
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5017 - loss: 0.3969 - val_auc_pr: 0.2921 - val_loss: 0.5153
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.5153 - loss: 0.3801 - val_auc_pr: 0.3052 - val_loss: 0.5132
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.5800 - loss: 0.3898 - val_auc_pr: 0.2953 - val_loss: 0.5131
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.6016 - loss: 0.3607 - val_auc_pr: 0.3241 - val_loss: 0.5521
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc_pr: 0.5626 - loss: 0.3895 - val_auc_pr: 0.3289 - val_loss: 0.4772
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.4906 - loss: 0.4046 - val_auc_pr: 0.3370 - val_loss: 0.5697
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.5175 - loss: 0.3793 - val_auc_pr: 0.3105 - val_loss: 0.5701
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc_pr: 0.4782 - loss: 0.3801 - val_auc_pr: 0.3427 - val_loss: 0.4940
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc_pr: 0.5827 - loss: 0.3806 - val_auc_pr: 0.3483 - val_loss: 0.5356
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.6191 - loss: 0.3773 - val_auc_pr: 0.3555 - val_loss: 0.5759
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc_pr: 0.5765 - loss: 0.3781 - val_auc_pr: 0.2651 - val_loss: 0.5528
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.5359 - loss: 0.3832 - val_auc_pr: 0.3384 - val_loss: 0.5146
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.6548 - loss: 0.3688 - val_auc_pr: 0.2842 - val_loss: 0.5754
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - auc_pr: 0.6530 - loss: 0.3541 - val_auc_pr: 0.2941 - val_loss: 0.4923
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc_pr: 0.6053 - loss: 0.3771 - val_auc_pr: 0.2947 - val_loss: 0.5031

# %%
def build_model_tuner(hp):
    regularization_l2 = tf.keras.regularizers.l2(hp.Float("l2_regularization", min_value=1e-6, max_value=1e-1, 
                                                sampling="log")) # Logarithmic scale for L2,
    units1 = hp.Int("units1", min_value=16, max_value=256, step=16)
    units2 = hp.Int("units2", min_value=16, max_value=128, step=16)
    units3 = hp.Int("units3", min_value=8, max_value=64, step=8)
    units4 = hp.Int("units4", min_value=8, max_value=64, step=8)
    units5 = hp.Int("units5", min_value=4, max_value=32, step=4)
    units6 = hp.Int("units6", min_value=2, max_value=8, step=2)
    learning_rate = hp.Float("learning_rate", min_value=1e-6, max_value=1e-1, sampling="log") # Logarithmic scale for learning_rate,

    model = Sequential([
            Input(shape=(X_train_transformed.shape[1],)),
            BatchNormalization(),
            Dense(units=units1,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=units2,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=units3,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=units4,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=units5,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=units6,
                activation="relu", 
                kernel_regularizer=regularization_l2),
            BatchNormalization(),
            Dropout(0.2),
            Dense(units=1,activation="sigmoid")
        ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                    loss="binary_crossentropy", 
                    metrics=[
                        tf.keras.metrics.AUC(curve="PR", name="auc_pr")  # AUC-PR metric
                    ])
                  
    return model


# Configurar el buscador
tuner = RandomSearch(
    build_model_tuner,  # La función que construye el modelo
    objective=Objective("val_auc_pr", direction="max"),  # optimizar el 
    executions_per_trial=3,  # Número de veces que se entrena cada combinación
    directory="my_tuner",  # Directorio donde guardar resultados
    project_name="grid_search_demo"  # Nombre del proyecto
)

# Buscar los mejores hiperparámetros
tuner.search(X_train_transformed, 
             y_train,
            validation_data=(X_test_transformed, y_test),
            epochs=50,
            batch_size=64)
#
# Obtener los mejores hiperparámetros
best_hps = tuner.get_best_hyperparameters(num_trials=10)[0]

print(f"Mejor número de neuronas capa 1: {best_hps.get('units1')}")
print(f"Mejor número de neuronas capa 2: {best_hps.get('units2')}")
print(f"Mejor número de neuronas capa 3: {best_hps.get('units3')}")
print(f"Mejor número de neuronas capa 4: {best_hps.get('units4')}")
print(f"Mejor número de neuronas capa 5: {best_hps.get('units5')}")
print(f"Mejor número de neuronas capa 6: {best_hps.get('units6')}")

print(f"Mejor learning rate: {best_hps.get('learning_rate')}")
print(f"Mejor regularizacion l2: {best_hps.get('l2_regularization')}")
# Out:
# Reloading Tuner from my_tuner/grid_search_demo/tuner0.json
# Mejor número de neuronas capa 1: 48
# Mejor número de neuronas capa 2: 128
# Mejor número de neuronas capa 3: 8
# Mejor número de neuronas capa 4: 16
# Mejor número de neuronas capa 5: 12
# Mejor número de neuronas capa 6: 8
# Mejor learning rate: 0.002557540247616812
# Mejor regularizacion l2: 0.01270923424139016

# %% [markdown]
# ### Cross-validation scheme

# %% [markdown]
# Convert pandas dataframes to numpy or tensorflow format.

# %%
# tensorflow, from numpy arrays
X_train_tensor = tf.convert_to_tensor(X_train_transformed.values, dtype=tf.float32)
y_train_tensor = tf.convert_to_tensor(y_train.values, dtype=tf.float32)

# numpy arrays from pandas df
X_train_np = X_train_transformed.values
y_train_np = y_train.values

# %% [markdown]
# Define a custom Cross-Validation tuner.

# %%
from keras_tuner.oracles import RandomSearchOracle
from keras_tuner.engine.tuner import Tuner

class CVTuner(Tuner):
    def __init__(self, oracle, hypermodel, cv_scheme, **kwargs):
        super().__init__(oracle=oracle, hypermodel=hypermodel, **kwargs)
        self.cv_scheme = cv_scheme
        self.hypermodel = hypermodel

    def run_trial(self, trial, X, y, batch_size=None, epochs=10):
        # Dynamically decide batch size
        batch_size = batch_size or trial.hyperparameters.Int("batch_size", min_value=16, max_value=128, step=16)
        
        val_scores = []

        for train_idx, val_idx in self.cv_scheme.split(X, y):
            try:
                X_train, X_val = X[train_idx], X[val_idx]
                y_train, y_val = y[train_idx], y[val_idx]
            except:
                    print("Train indices:", train_idx)
                    print("Validation indices:", val_idx)
                    raise RuntimeError
            


            model = self.hypermodel(trial.hyperparameters)
            history = model.fit(
                X_train, y_train,
                validation_data=(X_val, y_val),
                epochs=epochs,
                batch_size=batch_size,
                verbose=0
            )
            val_scores.append(max(history.history['val_auc_pr']))

        mean_val_score = mean(val_scores)
        self.oracle.update_trial(trial.trial_id, {'val_auc_pr': mean_val_score})
        self.save_model(trial.trial_id, model)


# Initialize the custom tuner
tuner = CVTuner(
    oracle=RandomSearchOracle(
        objective=Objective("val_auc_pr", direction="max"),
        max_trials=10,
        seed=42
    ),
    hypermodel=build_model_tuner,
    directory='cv_tuner_dir',
    project_name='cv_tuner_project',
    cv_scheme=cross_val
)

# Start the hyperparameter search
tuner.search(X_train_np, y_train_np, epochs=40, batch_size=64)
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 0.0015745         |0.0015745         |l2_regularization
# 16                |16                |units1
# 64                |64                |units2
# 24                |24                |units3
# 64                |64                |units4
# 12                |12                |units5
# 6                 |6                 |units6
# 2.1598e-06        |2.1598e-06        |learning_rate
